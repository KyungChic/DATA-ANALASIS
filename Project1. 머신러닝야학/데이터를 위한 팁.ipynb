# %%
import tensorflow as tf
import pandas as pd

path1 = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris2.csv"
iris1 = pd.read_csv(path1)

print(iris1.head())
print(iris1.columns)
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종
# 0   5.1  3.5    1.4   0.2   0
# 1   4.9  3.0    1.4   0.2   0
# 2   4.7  3.2    1.3   0.2   0
# 3   4.6  3.1    1.5   0.2   0
# 4   5.0  3.6    1.4   0.2   0
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')

# %%
#품종이 명목형인 데이터 호출
path2 = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv"
iris2 = pd.read_csv(path2)

print(iris2.head())
print(iris2.columns)
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')

# %%
#원핫인코딩 --  품종이 현재 int 형태기 때문에 원핫인코딩이 작동하지 않음(dtype이 category이나 object일 때 작동하기 때문)
incoding1 = pd.get_dummies(iris)
print(incoding1.head())
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종
# 0   5.1  3.5    1.4   0.2   0
# 1   4.9  3.0    1.4   0.2   0
# 2   4.7  3.2    1.3   0.2   0
# 3   4.6  3.1    1.5   0.2   0
# 4   5.0  3.6    1.4   0.2   0

# %%
#데이터 타입 보기
print(iris1.dtypes)
print(iris2.dtypes)
# Out:
# 꽃잎길이     float64
# 꽃잎폭      float64
# 꽃받침길이    float64
# 꽃받침폭     float64
# 품종         int64
# dtype: object
# 꽃잎길이     float64
# 꽃잎폭      float64
# 꽃받침길이    float64
# 꽃받침폭     float64
# 품종        object
# dtype: object

# %%
#iris1의 품종 데이터타입 변환하기

iris1['품종'] = iris1['품종'].astype('category')
print(iris1.dtypes)
# Out:
# 꽃잎길이      float64
# 꽃잎폭       float64
# 꽃받침길이     float64
# 꽃받침폭      float64
# 품종       category
# dtype: object

# %%
#다시 원핫인코딩

incoding2 = pd.get_dummies(iris1)
incoding2.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_0  품종_1  품종_2
# 0   5.1  3.5    1.4   0.2     1     0     0
# 1   4.9  3.0    1.4   0.2     1     0     0
# 2   4.7  3.2    1.3   0.2     1     0     0
# 3   4.6  3.1    1.5   0.2     1     0     0
# 4   5.0  3.6    1.4   0.2     1     0     0

# %%
################################################################################################3

# %%
#NA값이 있는지 확인하기

print(iris1.isna())
print(iris1.isna().sum())
# Out:
#       꽃잎길이    꽃잎폭  꽃받침길이   꽃받침폭     품종
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 145  False  False  False  False  False
# 146  False  False  False  False  False
# 147  False  False  False  False  False
# 148  False  False  False  False  False
# 149  False   True  False  False  False
#
# [150 rows x 5 columns]
# 꽃잎길이     0
# 꽃잎폭      1
# 꽃받침길이    0
# 꽃받침폭     0
# 품종       0
# dtype: int64

# %%
#NA값을 채우는 방법 중 하나 : NA값에 나머지 값들의 평균값을 넣어주기.

##NA값이 있으면 모델링 불가함.

# %%
#평균값구하기

mean = iris1['꽃잎폭'].mean()
print(mean)
# Out:
# 3.0543624161073835

# %%
#평균값을 NA값에 채우기

iris1['꽃잎폭'] = iris1['꽃잎폭'].fillna(mean)

print(iris1.isna())

print(iris1.tail())
# Out:
#       꽃잎길이    꽃잎폭  꽃받침길이   꽃받침폭     품종
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 145  False  False  False  False  False
# 146  False  False  False  False  False
# 147  False  False  False  False  False
# 148  False  False  False  False  False
# 149  False  False  False  False  False
#
# [150 rows x 5 columns]
#      꽃잎길이       꽃잎폭  꽃받침길이  꽃받침폭 품종
# 145   6.7  3.000000    5.2   2.3  2
# 146   6.3  2.500000    5.0   1.9  2
# 147   6.5  3.000000    5.2   2.0  2
# 148   6.2  3.400000    5.4   2.3  2
# 149   5.9  3.054362    5.1   1.8  2
