# %%
import pandas as pd
import tensorflow as tf

path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(path)

# %%
indep = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax','ptratio', 'b', 'lstat']]
dep = boston[['medv']]

print(indep.shape, dep.shape)
# Out:
# (506, 13) (506, 1)

# %%
x = tf.keras.layers.Input(shape = [13])
y = tf.keras.layers.Dense(1)(x)

model = tf.keras.models.Model(x,y)
model.compile(loss = 'mse')

# %%
model.fit(indep, dep, epochs = 1000, verbose = 0)
model.fit(indep, dep, epochs = 10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.4614
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.0328
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.2324
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.4808
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9524
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.8223
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.1583
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.7607
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.2340
# Epoch 10/10
# 16/16 [==============================] - 0s 986us/step - loss: 24.1263

# %%
model.predict(indep[0:5])
# Out:
# array([[28.725565],
#        [23.48933 ],
#        [30.116606],
#        [28.886126],
#        [28.4997  ]], dtype=float32)

# %%
dep[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
indep[0:5]
# Out:
#       crim    zn  indus  chas    nox  ...  rad  tax  ptratio       b  lstat
# 0  0.00632  18.0   2.31     0  0.538  ...    1  296     15.3  396.90   4.98
# 1  0.02731   0.0   7.07     0  0.469  ...    2  242     17.8  396.90   9.14
# 2  0.02729   0.0   7.07     0  0.469  ...    2  242     17.8  392.83   4.03
# 3  0.03237   0.0   2.18     0  0.458  ...    3  222     18.7  394.63   2.94
# 4  0.06905   0.0   2.18     0  0.458  ...    3  222     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
model.get_weights()
# Out:
# [array([[-0.09316853],
#         [ 0.05068026],
#         [-0.03165837],
#         [ 2.6715548 ],
#         [ 0.6623172 ],
#         [ 5.3583546 ],
#         [-0.01278394],
#         [-1.0084733 ],
#         [ 0.1848535 ],
#         [-0.01180474],
#         [-0.4580867 ],
#         [ 0.01226585],
#         [-0.461029  ]], dtype=float32), array([5.0033875], dtype=float32)]

# %%
# -0.09316853 부터 -0.461029까지가 각 독립변수에 대한 가중치
# 5.0033875 는 편향(bias)
